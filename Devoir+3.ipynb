# %% [markdown]
# # Devoir 3 qui va valoir mon 10 points !

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib as mp

# %%
ati = pd.read_csv("ati.csv")

# %%
ati
# Out:
#        year  month request_number  \
# 0      2016      3   A-2015-00070
# 1      2015      4   A-2015-00001
# 2      2015      4   A-2014-00219
# 3      2015      4   A-2014-00218
# 4      2015      4   A-2014-00217
# 5      2015      4   A-2014-00216
# 6      2015      4   A-2014-00214
# 7      2015      4   A-2014-00210
# 8      2015      4   A-2014-00213
# 9      2015      6   A-2015-00012
# 10     2015      4   A-2014-00212
# 11     2015      4   A-2014-00200
# 12     2015      4   A-2014-00140
# 13     2015      5   A-2015-00003
# 14     2015      4   A-2014-00112
# 15     2015      5   A-2014-00211
# 16     2015      4   A-2014-00098
# 17     2015      4   A-2014-00070
# 18     2015      4   A-2015-00009
# 19     2015      5   A-2015-00011
# 20     2015      5   A-2015-00010
# 21     2015      5   A-2015-00006
# 22     2015      5   A-2014-00209
# 23     2015      5   A-2014-00145
# 24     2015      5   A-2014-00137
# 25     2015      5   A-2014-00134
# ...

# %%
ati.dtypes
# Out:
# year                int64
# month               int64
# request_number     object
# summary_en         object
# summary_fr         object
# disposition        object
# pages               int64
# owner_org          object
# owner_org_title    object
# dtype: object

# %%
ati.count()
# Out:
# year               28757
# month              28757
# request_number     28744
# summary_en         28737
# summary_fr         28663
# disposition        28736
# pages              28757
# owner_org          28757
# owner_org_title    28757
# dtype: int64

# %%
ati.year.value_counts()
# Out:
# 2016    15016
# 2015    12630
# 2017     1111
# Name: year, dtype: int64

# %%
ati.year.value_counts().plot(kind="pie", title="Nombre de demandes d'accès à l'information depuis 2015")

# %% [markdown]
# Grâce à la fonction précédente, j'ai pu remarquer que le nombre de demandes d'accès à l'information a été plus grand en 2016 qu'en 2015. Cependant, pour 2017, il est encore trop tôt pour d.terminer ce qui en sera. J'ai réussi à illuster le tout dans un graphique de type tarte pour que ce soit plus beau visuellement.

# %%
ati.pages.max()
# Out:
# 2435124351

# %%
ati.pages.min()
# Out:
# 0

# %%
ati.pages.sum()
# Out:
# 2441714166

# %% [markdown]
# Avec les trois fonctions précédentes, j'ai pu trouver que le plus grand nombre de pages pour un document est de 2435124351, alors que le minimum est de 0. La somme totale des pages de documentation obtenue par des demandes d'accès à l'information depuis 2015 est quant à elle de 2441714166.

# %%
ati.owner_org_title.value_counts()
# Out:
# National Defence | Défense nationale                                                                                                                             2605
# Global Affairs Canada | Affaires mondiales Canada                                                                                                                1650
# Employment and Social Development Canada | Emploi et Développement social Canada                                                                                 1541
# Immigration, Refugees and Citizenship Canada | Immigration, Réfugiés et Citoyenneté Canada                                                                       1323
# Health Canada | Santé Canada                                                                                                                                     1164
# ...

# %% [markdown]
# Depuis 2015, la Défense nationale a été l'institution qui a reçue le plus de demande d'accès à l'information avec un grand total de 2605 demandes alors que l'Ombudsman de la Défense nationale et des Forces canadiennes, le Conseil des produits agricoles du Canada, le Musée canadien de l'immigration du Quai 21 ainsi que la Commission canadienne des grains sont les institutions qui ont reçu le moins de ces demandes avec une seule.
